# %%
import pandas as pd
import numpy as np

# %%
# Data parameters
YEAR: int = 2024
WEEK: int = 3

# Wagering parameters
WAGER_SIZE = 20
CONFIDENCE_THRESHOLD = 0.75

# %%
df = pd.read_csv(f"./data/weekly_predictions_{YEAR}_{WEEK}.csv")

# %%
df.head()
# Out:
#            game_id  season game_type  week     gameday   weekday gametime  \
# 0   2024_03_NE_NYJ    2024       REG     3  2024-09-19  Thursday    20:15
# 1  2024_03_NYG_CLE    2024       REG     3  2024-09-22    Sunday    13:00
# 2  2024_03_CHI_IND    2024       REG     3  2024-09-22    Sunday    13:00
# 3  2024_03_HOU_MIN    2024       REG     3  2024-09-22    Sunday    13:00
# 4   2024_03_PHI_NO    2024       REG     3  2024-09-22    Sunday    13:00
#
#   away_team  away_score home_team  ...  home_qb_id     away_qb_name  \
# 0        NE         NaN       NYJ  ...  00-0023459  Jacoby Brissett
# 1       NYG         NaN       CLE  ...  00-0033537     Daniel Jones
# 2       CHI         NaN       IND  ...  00-0039164   Caleb Williams
# 3       HOU         NaN       MIN  ...  00-0034869      C.J. Stroud
# 4       PHI         NaN        NO  ...  00-0031280      Jalen Hurts
#
#          home_qb_name     away_coach       home_coach  referee  stadium_id  \
# 0       Aaron Rodgers     Jerod Mayo     Robert Saleh      NaN       NYC01
# 1      Deshaun Watson   Brian Daboll  Kevin Stefanski      NaN       CLE00
# 2  Anthony Richardson  Matt Eberflus   Shane Steichen      NaN       IND00
# 3         Sam Darnold   DeMeco Ryans  Kevin O'Connell      NaN       MIN01
# 4          Derek Carr  Nick Sirianni     Dennis Allen      NaN       NOR00
#
#                    stadium predicted_winner  win_probability
# 0          MetLife Stadium               NE         0.581463
# 1      FirstEnergy Stadium              CLE         0.781090
# 2        Lucas Oil Stadium              IND         0.537212
# 3        U.S. Bank Stadium              MIN         0.751295
# 4  Mercedes-Benz Superdome               NO         0.929497
#
# [5 rows x 48 columns]

# %%
# Find best value moneyline bets based on odds, wager size, and predicted win probability

# %%
# Function to calculate implied probability from moneyline
def implied_prob(moneyline):
    if moneyline > 0:
        return 100 / (moneyline + 100)
    else:
        return -moneyline / (-moneyline + 100)


# Function to calculate potential profit from a moneyline bet
def calculate_profit(moneyline, wager):
    if moneyline > 0:
        return wager * (moneyline / 100)
    else:
        return wager * (100 / -moneyline)


# Function to calculate expected profit
def expected_profit(win_probability, moneyline, wager):
    potential_payout = calculate_profit(moneyline, wager)
    return (win_probability * potential_payout) - ((1 - win_probability) * wager)

# %%
# Calculate implied probabilities for home and away teams from the moneyline
df["away_implied_prob"] = df["away_moneyline"].apply(implied_prob)
df["home_implied_prob"] = df["home_moneyline"].apply(implied_prob)

# Compare implied probability with model's predicted probability for value bets
df["away_value_bet"] = df["win_probability"] < df["away_implied_prob"]
df["home_value_bet"] = df["win_probability"] > df["home_implied_prob"]

# Calculate potential profit for away and home teams
df["away_potential_profit"] = df["away_moneyline"].apply(
    lambda x: calculate_profit(x, WAGER_SIZE)
)
df["home_potential_profit"] = df["home_moneyline"].apply(
    lambda x: calculate_profit(x, WAGER_SIZE)
)

# Calculate the projected profit based on the predicted winner (use home or away moneyline based on the prediction)
df["projected_profit"] = np.where(
    df["predicted_winner"] == df["away_team"],
    df["away_potential_profit"],  # Profit if away team wins
    df["home_potential_profit"],  # Profit if home team wins
)

# %%
# Display the top rows with the projected profit
sorted_df = (
    df[
        [
            "away_team",
            "home_team",
            "predicted_winner",
            "win_probability",
            "away_moneyline",
            "home_moneyline",
            "projected_profit",
        ]
    ]
    .sort_values(by="projected_profit", ascending=False)
    .head(10)
)

# %%
# Filter for win probability above threshold and value bets
filtered_df = (
    df.loc[
        (df["win_probability"] > CONFIDENCE_THRESHOLD),
        [
            "away_team",
            "home_team",
            "predicted_winner",
            "win_probability",
            "away_moneyline",
            "home_moneyline",
            "projected_profit",
        ],
    ]
    .sort_values(by="projected_profit", ascending=False)
    .head(10)
)


display(filtered_df)
# Out:
#    away_team home_team predicted_winner  win_probability  away_moneyline  \
# 4        PHI        NO               NO         0.929497          -142.0
# 13        KC       ATL               KC         0.841972          -218.0
# 14       JAX       BUF              BUF         0.826018           225.0
# 6        DEN        TB               TB         0.897229           260.0
# 1        NYG       CLE              CLE         0.781090           270.0
# 8        CAR        LV               LV         0.851380           270.0
# 3        HOU       MIN              MIN         0.751295             NaN
#
#     home_moneyline  projected_profit
# 4            120.0         24.000000
# 13           180.0          9.174312
# 14          -278.0          7.194245
# 6           -325.0          6.153846
# 1           -340.0          5.882353
# 8           -340.0          5.882353
# 3              NaN               NaN

# %%
# Bets Taken So Far
TEAMS_BET = ["NO", "PHI", "NE", "KC", "BUF"]

# Game Rows
game_rows = df.loc[
    (df["away_team"].isin(TEAMS_BET) | df["home_team"].isin(TEAMS_BET)),
    [
        "away_team",
        "home_team",
        "predicted_winner",
        "win_probability",
        "away_moneyline",
        "home_moneyline",
        "projected_profit",
    ],
]

display(game_rows)
# Out:
#    away_team home_team predicted_winner  win_probability  away_moneyline  \
# 0         NE       NYJ               NE         0.581463           245.0
# 4        PHI        NO               NO         0.929497          -142.0
# 13        KC       ATL               KC         0.841972          -218.0
# 14       JAX       BUF              BUF         0.826018           225.0
#
#     home_moneyline  projected_profit
# 0           -305.0         49.000000
# 4            120.0         24.000000
# 13           180.0          9.174312
# 14          -278.0          7.194245
